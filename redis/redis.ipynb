# %%
from FogifySDK import FogifySDK
fogify = FogifySDK("http://controller:5000", "docker-compose.yaml")

# %%
fogify.deploy()
# Out:
# Deploy process: 100%|██████████| 7/7 [00:10<00:00,  1.44s/it]
# {'message': "The services are deployed ( {'master': 1, 'slave': 3, 'sentinel': 3} )"}

# %%
fogify.info()
# Out:
# {'fogify_master': [{'ID': 'u3ay5vhinplcimf4erf9d1ms8',
#    'Version': {'Index': 168},
#    'CreatedAt': '2021-02-07T23:37:50.39736041Z',
#    'UpdatedAt': '2021-02-07T23:37:50.930274745Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'redis:alpine@sha256:d2b1b0bf521f55381c81b1bc0218aec4ddc92fb545e9e8492e8ff324462eed58',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Env': ['NODE_TYPE=REDIS_MASTER'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 1200000000,
#       'MemoryBytes': 2147483648},
#      'Reservations': {'NanoCPUs': 1200000000, 'MemoryBytes': 2147483648}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'},
#       {'OS': 'linux'},
#       {'OS': 'linux'},
#       {'Architecture': 'arm64', 'OS': 'linux'},
#       {'Architecture': '386', 'OS': 'linux'},
#       {'Architecture': 'ppc64le', 'OS': 'linux'},
#       {'Architecture': 's390x', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['master']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'kd378zfaigguyr94jfw6c714i',
#    'Slot': 1,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:50.866943606Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': 'f1d139de918040c791a0fbc0590d5a642b51d78fce666de7da275d4c20028b3c',
#      'PID': 32540,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.35/24']}]}],
#  'fogify_slave': [{'ID': '4ud6ylcq1gxm4qd57m4uizeo9',
#    'Version': {'Index': 160},
#    'CreatedAt': '2021-02-07T23:37:48.075832417Z',
#    'UpdatedAt': '2021-02-07T23:37:49.02171929Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'redis:alpine@sha256:d2b1b0bf521f55381c81b1bc0218aec4ddc92fb545e9e8492e8ff324462eed58',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '--replicaof', 'master', '6379'],
#      'Env': ['NODE_TYPE=REDIS_SLAVE'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 1200000000,
#       'MemoryBytes': 2147483648},
#      'Reservations': {'NanoCPUs': 1200000000, 'MemoryBytes': 2147483648}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'},
#       {'OS': 'linux'},
#       {'OS': 'linux'},
#       {'Architecture': 'arm64', 'OS': 'linux'},
#       {'Architecture': '386', 'OS': 'linux'},
#       {'Architecture': 'ppc64le', 'OS': 'linux'},
#       {'Architecture': 's390x', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['slave']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'w6jic34rk1k8xvj3og4l569ub',
#    'Slot': 3,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:48.988831105Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '47c6b572961120948762323b2d71b55b835f347cb4b16685b352b4daaecbc9ad',
#      'PID': 32188,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.30/24']}]},
#   {'ID': 'hzx9ucg4vh2u4q3xq9kamisv6',
#    'Version': {'Index': 160},
#    'CreatedAt': '2021-02-07T23:37:48.075813504Z',
#    'UpdatedAt': '2021-02-07T23:37:49.021658166Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'redis:alpine@sha256:d2b1b0bf521f55381c81b1bc0218aec4ddc92fb545e9e8492e8ff324462eed58',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '--replicaof', 'master', '6379'],
#      'Env': ['NODE_TYPE=REDIS_SLAVE'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 1200000000,
#       'MemoryBytes': 2147483648},
#      'Reservations': {'NanoCPUs': 1200000000, 'MemoryBytes': 2147483648}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'},
#       {'OS': 'linux'},
#       {'OS': 'linux'},
#       {'Architecture': 'arm64', 'OS': 'linux'},
#       {'Architecture': '386', 'OS': 'linux'},
#       {'Architecture': 'ppc64le', 'OS': 'linux'},
#       {'Architecture': 's390x', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['slave']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'w6jic34rk1k8xvj3og4l569ub',
#    'Slot': 2,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:48.964529666Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '3536b5887c1f253254fcd6d30dbde707c8252d70c344584b5e33630d238251be',
#      'PID': 32110,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.32/24']}]},
#   {'ID': 'uqr7pn5pdox7p3u74yy7b67eq',
#    'Version': {'Index': 161},
#    'CreatedAt': '2021-02-07T23:37:48.075782463Z',
#    'UpdatedAt': '2021-02-07T23:37:50.123891604Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'redis:alpine@sha256:d2b1b0bf521f55381c81b1bc0218aec4ddc92fb545e9e8492e8ff324462eed58',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '--replicaof', 'master', '6379'],
#      'Env': ['NODE_TYPE=REDIS_SLAVE'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 1200000000,
#       'MemoryBytes': 2147483648},
#      'Reservations': {'NanoCPUs': 1200000000, 'MemoryBytes': 2147483648}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'},
#       {'OS': 'linux'},
#       {'OS': 'linux'},
#       {'Architecture': 'arm64', 'OS': 'linux'},
#       {'Architecture': '386', 'OS': 'linux'},
#       {'Architecture': 'ppc64le', 'OS': 'linux'},
#       {'Architecture': 's390x', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['slave']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'w6jic34rk1k8xvj3og4l569ub',
#    'Slot': 1,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:50.03121296Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '7d2140a37c69168cbd3d9479a9a6e4b9680365ff47905698c810d35c3d2b088b',
#      'PID': 32186,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.31/24']}]}],
#  'fogify_sentinel': [{'ID': '126qra421vwumu1sekh4jgxmp',
#    'Version': {'Index': 175},
#    'CreatedAt': '2021-02-07T23:37:53.371355165Z',
#    'UpdatedAt': '2021-02-07T23:37:54.037523328Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'datalabauth/redis-sentinel:latest@sha256:7cf65d97990ce07bc668c9d75e211d10d0f1cc3b74178c70fbff66af0e207a63',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '/sentinel.conf', '--sentinel'],
#      'Env': ['NODE_TYPE=REDIS_SENTINEL'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912},
#      'Reservations': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['sentinel']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'xmk4a28h9n88xmodwr526zcqs',
#    'Slot': 3,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:54.013961208Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '06bec11aef41d15aeb2541decb35311ae59f231de06cd38826cff5817f7385f3',
#      'PID': 769,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.39/24']}]},
#   {'ID': 'cilfaxg6kvc6nhvenfcb5fm7i',
#    'Version': {'Index': 177},
#    'CreatedAt': '2021-02-07T23:37:53.371229383Z',
#    'UpdatedAt': '2021-02-07T23:37:55.341248121Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'datalabauth/redis-sentinel:latest@sha256:7cf65d97990ce07bc668c9d75e211d10d0f1cc3b74178c70fbff66af0e207a63',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '/sentinel.conf', '--sentinel'],
#      'Env': ['NODE_TYPE=REDIS_SENTINEL'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912},
#      'Reservations': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['sentinel']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'xmk4a28h9n88xmodwr526zcqs',
#    'Slot': 2,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:55.261811105Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '20e4acf22b05bb7d425d9508d4de0051018d058cbe3b36319f7b4addca9c441e',
#      'PID': 913,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.38/24']}]},
#   {'ID': 'mfmbi2tn5gcc2od4s18rafijz',
#    'Version': {'Index': 176},
#    'CreatedAt': '2021-02-07T23:37:53.370990209Z',
#    'UpdatedAt': '2021-02-07T23:37:54.238798292Z',
#    'Labels': {},
#    'Spec': {'ContainerSpec': {'Image': 'datalabauth/redis-sentinel:latest@sha256:7cf65d97990ce07bc668c9d75e211d10d0f1cc3b74178c70fbff66af0e207a63',
#      'Labels': {'com.docker.stack.namespace': 'fogify'},
#      'Args': ['redis-server', '/sentinel.conf', '--sentinel'],
#      'Env': ['NODE_TYPE=REDIS_SENTINEL'],
#      'Privileges': {'CredentialSpec': None, 'SELinuxContext': None},
#      'Isolation': 'default'},
#     'Resources': {'Limits': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912},
#      'Reservations': {'NanoCPUs': 300000000, 'MemoryBytes': 536870912}},
#     'Placement': {'Platforms': [{'Architecture': 'amd64', 'OS': 'linux'}]},
#     'Networks': [{'Target': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Aliases': ['sentinel']}],
#     'ForceUpdate': 0},
#    'ServiceID': 'xmk4a28h9n88xmodwr526zcqs',
#    'Slot': 1,
#    'NodeID': 'skbc6zmbtbamwhldmj8ew6m1n',
#    'Status': {'Timestamp': '2021-02-07T23:37:54.200059875Z',
#     'State': 'running',
#     'Message': 'started',
#     'ContainerStatus': {'ContainerID': '7170fbe9b6c7b5843278529a1928a47ecf19e5517e08984806819f1326864e3c',
#      'PID': 920,
#      'ExitCode': 0},
#     'PortStatus': {}},
#    'DesiredState': 'running',
#    'NetworksAttachments': [{'Network': {'ID': 't7a2bhd4z9ayx0o79qpgm4k8v',
#       'Version': {'Index': 12},
#       'CreatedAt': '2021-02-07T23:06:34.695364311Z',
#       'UpdatedAt': '2021-02-07T23:06:34.69659118Z',
#       'Spec': {'Name': 'internet',
#        'Labels': {},
#        'DriverConfiguration': {'Name': 'overlay'},
#        'Attachable': True,
#        'IPAMOptions': {'Driver': {'Name': 'default'}},
#        'Scope': 'swarm'},
#       'DriverState': {'Name': 'overlay',
#        'Options': {'com.docker.network.driver.overlay.vxlanid_list': '4097'}},
#       'IPAMOptions': {'Driver': {'Name': 'default'},
#        'Configs': [{'Subnet': '10.0.1.0/24', 'Gateway': '10.0.1.1'}]}},
#      'Addresses': ['10.0.1.37/24']}]}]}

# %%
fogify.command('redis-master-node', '/usr/local/bin/redis-cli set institute "AUTH"')
# Out:
# {'message': 'OK'}

# %%
help(fogify)
# Out:
# Help on FogifySDK in module FogifySDK.FogifySDK object:
#
# class FogifySDK(builtins.object)
#  |  FogifySDK(url, docker_compose=None)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, url, docker_compose=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  action(self, action_type, **kwargs)
#  |
#  |  add_deployment_node(self, label, service, device, networks=[], replicas=1)
#  |
#  |  add_device(self, name, cpu_cores, cpu_freq, memory, disk='')
#  |
#  |  add_network(self, name, uplink, downlink, capacity)
#  |
#  |  check_docker_swarm_existence(self)
#  |
#  |  clean_annotations(self)
#  |
#  |  clean_metrics(self)
#  |
#  |  command(self, instance_type, command, num_of_instances=1)
#  |
#  |  deploy(self, timeout=120)
#  |
#  |  get_annotations(self)
#  |
#  |  get_metrics(self, service=None, from_timestamp=None, to_timestamp=None)
#  |
#  |  get_metrics_from(self, service)
#  |
#  |  get_url(self, path='')
#  |
#  |  horizontal_scaling_down(self, instance_type, num_of_instances=1)
#  |
#  |  horizontal_scaling_up(self, instance_type, num_of_instances=1)
#  |
#  |  info(self)
#  |
#  |  parse_docker_swarm(self)
#  |
#  |  plot(self, ax, service=None, metric=None, func=None, label=None, duration={}, style={})
#  |
#  |  plot_annotations(self, ax, start=None, stop=None, label='annotation', colors_gist='gist_yarg', linestyle='--')
#  |
#  |  scenario_execution(self, name=None, remove_previous_metrics=True)
#  |
#  |  stress(self, instance_type, duration=60, num_of_instances=1, cpu=None, io=None, vm=None, vm_bytes=None)
#  |
#  |  undeploy(self, timeout=120)
#  |
#  |  update_network(self, instance_type, network, network_characteristics={}, num_of_instances=1)
#  |
#  |  vertical_scaling(self, instance_type, num_of_instances=1, cpu=None, memory=None)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  upload_file
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  Action_type = <enum 'Action_type'>
#  |      An enumeration.
#  |
#  |  devices = []
#  |
#  |  docker_compose = None
#  |
#  |  docker_swarm_rep = None
#  |
#  |  networks = []
#  |
#  |  services = []
#  |
#  |  topology = []
#  |
#  |  url = None

# %%
fogify.undeploy()
# Out:
# {'message': 'The system is available.'}
